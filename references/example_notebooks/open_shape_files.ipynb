# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np

#matplotlib in line

# %%
# open shape file (will take minutes)
# modify path to correct location
all_impact_data = gpd.read_file("C:/Users/user/Desktop/Code/All_impact_sim.shp")
all_impact_data.head()      # obtain the first five rows as an example

# %%
# filter to get certain attributes
df_ISO5_2030 = all_impact_data.filter(['X','Y','country','IMAGE_rfix','ISO5_2030',"geometry"])
df_ISO5_2030.head()

# %%
# open shape file (will take minutes)
# modify path to correct location
all_CDDHDD_Q_sim_data = gpd.read_file("C://Users/user/Desktop/Code/All_CDDHDD_Q_sim.shp")
all_CDDHDD_Q_sim_data.head()
